# %% [markdown]
# # Лабараторная №1. Основый предобработки данных

# %% [markdown]
# Используйте файл своей группы. <br>
# Загрузите его в DataFrame и ответьте на вопросы, используя инстурменты из файла preprocessing.ipynb.
#
#
# #### Воспросы
# 1. В какой шкале представлены все признаки в наборе?<br>
# 2. Укажите признак с наименьшей дисперсией.<br>
# 3. Среднее какого признака отличается для двух классов сильнее всего?<br>
# 4. В каком классе больше всего skilled работников?<br>
# 5. Есть ли в наборе признаки с выбросами? Какие?<br>
# 6. Сколько пропущенных значений в наборе?<br>
# 7. Попытайтесь заполнить пропущенные значения.<br>
# 8. Как минимум для одного признака каждого типа постройте диаграмму, которая может помочь его исследовать.<br>
# 9. Проанализируйте взаимосвязи признаков с помощью scatter-plot матрицы и тепловой карты корреляций. Какие выводы можно сделать?<br>
# 10. Какой признак(и) имеет смысл стандартизировать? Почему?<br>
# 11. Придумайте 1 новый признак, попытайтесь объяснить, почему он информативный.<br>

# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt

import seaborn as sns

from sklearn import datasets
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler

np.set_printoptions(precision=3)
pd.set_option('precision', 3)

sns.set()

# %%
path='credit_3530203_70101.csv'
credit_df = pd.read_csv(path, index_col=0)
credit_df
# Out:
#     checking_status  duration                  credit_history  \
# 1          0<=X<200      18.0                   existing paid
# 2             >=200       6.0  critical/other existing credit
# 3                <0      24.0                   existing paid
# 4                <0      36.0                   existing paid
# 5             >=200       9.0                   existing paid
# ..              ...       ...                             ...
# 498     no checking      12.0                   existing paid
# 499              <0      30.0                   existing paid
# 500     no checking      12.0                   existing paid
# 501              <0      45.0                   existing paid
# 502        0<=X<200      45.0  critical/other existing credit
#
#                  purpose  credit_amount savings_status employment  \
# 1               radio/tv         1301.0           <100        >=7
# 2                new car         1323.0     100<=X<500        >=7
# 3                new car         3123.0           <100         <1
# 4               used car         5493.0           <100        >=7
# 5               radio/tv         1126.0     100<=X<500        >=7
# ..                   ...            ...            ...        ...
# 498  furniture/equipment         1736.0           <100     4<=X<7
# 499             used car         3857.0           <100     1<=X<4
# 500             radio/tv          804.0           <100        >=7
# 501             radio/tv         1845.0           <100     1<=X<4
# 502             used car         4576.0     100<=X<500          0
#
#      installment_commitment other_parties property_magnitude   age  \
# 1                       4.0     guarantor        real estate  32.0
# 2                       2.0          none                car  28.0
# 3                       4.0          none     life insurance  27.0
# 4                       2.0          none  no known property  42.0
# 5                       2.0          none        real estate  49.0
# ..                      ...           ...                ...   ...
# 498                     3.0          none        real estate  31.0
# 499                     4.0          none     life insurance  40.0
# 500                     4.0          none                car  38.0
# 501                     4.0          none  no known property  23.0
# 502                     3.0          none                car  27.0
#
#     other_payment_plans   housing  existing_credits  \
# 1                  none       own               1.0
# 2                  none       own               2.0
# 3                  none       own               1.0
# 4                  none  for free               1.0
# 5                  none       own               1.0
# ..                  ...       ...               ...
# 498                none       own               1.0
# 499                none       own               1.0
# 500                none       own               1.0
# 501                none  for free               1.0
# 502                none       own               1.0
#
#                            job  num_dependents foreign_worker class
# 1           unskilled resident             1.0            yes  good
# 2                      skilled             2.0            yes  good
# 3                      skilled             1.0            yes   bad
# 4                      skilled             2.0            yes  good
# 5                      skilled             1.0            yes  good
# ..                         ...             ...            ...   ...
# 498         unskilled resident             1.0            yes  good
# 499  high qualif/self emp/mgmt             1.0            yes  good
# 500                    skilled             1.0            yes  good
# 501                    skilled             1.0            yes   bad
# 502                    skilled             1.0            yes  good
#
# [502 rows x 18 columns]

# %%
print(credit_df.var().min())
credit_df.var()
# Out:
# 0.1396092277596202
# duration                  1.625e+02
# credit_amount             7.967e+06
# installment_commitment    1.224e+00
# age                       1.271e+02
# existing_credits          3.439e-01
# num_dependents            1.396e-01
# dtype: float64

# %%
abs(credit_df.where(credit_df['class']=='good').mean() - credit_df.where(credit_df['class']=='bad').mean())
# Out:
# duration                    4.982
# credit_amount             573.110
# installment_commitment      0.103
# age                         3.304
# existing_credits            0.099
# num_dependents              0.022
# dtype: float64

# %%
if(credit_df["class"].where(credit_df['class'] == 'good').where(credit_df['job'] == 'skilled').count() - 
credit_df["class"].where(credit_df['class'] == 'bad').where(credit_df['job'] == 'skilled').count() > 0):
    print('good')
else:
    print('bad')
# Out:
# good

# %%
fig, axs = plt.subplots(figsize=(12,7))
sns.boxplot(data=credit_df)
# Out:
# <AxesSubplot:>

# %%
fig, axs = plt.subplots(figsize=(12,7))
sns.boxplot(x='duration', data=credit_df)
# Out:
# <AxesSubplot:xlabel='duration'>

# %%
fig, axs = plt.subplots(figsize=(12,7))
sns.boxplot(x='age', data=credit_df)
# Out:
# <AxesSubplot:xlabel='age'>

# %%
fig, axs = plt.subplots(figsize=(12,7))
sns.boxplot(x='installment_commitment', data=credit_df)
# Out:
# <AxesSubplot:xlabel='installment_commitment'>

# %%
fig, axs = plt.subplots(figsize=(12,7))
sns.boxplot(x='existing_credits', data=credit_df)
# Out:
# <AxesSubplot:xlabel='existing_credits'>

# %%
credit_df1 = credit_df.replace(-1, np.NaN).replace('no checking', np.NaN).replace('no known savings', np.NaN).replace('unemployed', np.NaN).replace('none', np.NaN)
no_zero_columns = list (set(credit_df1.columns))
(credit_df1[no_zero_columns].isnull()).sum().sum()
# Out:
# 1204

# %%
credit_df1['checking_status'] = credit_df1['checking_status'].fillna(credit_df1['checking_status'].mode().max())
credit_df1['duration'] = credit_df1['duration'].fillna(credit_df1['duration'].mode().max())
credit_df1['savings_status'] = credit_df1['savings_status'].fillna(credit_df1['savings_status'].mode().max())
credit_df1['employment'] = credit_df1['employment'].fillna(credit_df1['employment'].mode().max())
credit_df1
# Out:
#     checking_status  duration                  credit_history  \
# 1          0<=X<200      18.0                   existing paid
# 2             >=200       6.0  critical/other existing credit
# 3                <0      24.0                   existing paid
# 4                <0      36.0                   existing paid
# 5             >=200       9.0                   existing paid
# ..              ...       ...                             ...
# 498              <0      12.0                   existing paid
# 499              <0      30.0                   existing paid
# 500              <0      12.0                   existing paid
# 501              <0      45.0                   existing paid
# 502        0<=X<200      45.0  critical/other existing credit
#
#                  purpose  credit_amount savings_status employment  \
# 1               radio/tv         1301.0           <100        >=7
# 2                new car         1323.0     100<=X<500        >=7
# 3                new car         3123.0           <100         <1
# 4               used car         5493.0           <100        >=7
# 5               radio/tv         1126.0     100<=X<500        >=7
# ..                   ...            ...            ...        ...
# 498  furniture/equipment         1736.0           <100     4<=X<7
# 499             used car         3857.0           <100     1<=X<4
# 500             radio/tv          804.0           <100        >=7
# 501             radio/tv         1845.0           <100     1<=X<4
# 502             used car         4576.0     100<=X<500          0
#
#      installment_commitment other_parties property_magnitude   age  \
# 1                       4.0     guarantor        real estate  32.0
# 2                       2.0           NaN                car  28.0
# 3                       4.0           NaN     life insurance  27.0
# 4                       2.0           NaN  no known property  42.0
# 5                       2.0           NaN        real estate  49.0
# ..                      ...           ...                ...   ...
# 498                     3.0           NaN        real estate  31.0
# 499                     4.0           NaN     life insurance  40.0
# 500                     4.0           NaN                car  38.0
# 501                     4.0           NaN  no known property  23.0
# 502                     3.0           NaN                car  27.0
#
#     other_payment_plans   housing  existing_credits  \
# 1                   NaN       own               1.0
# 2                   NaN       own               2.0
# 3                   NaN       own               1.0
# 4                   NaN  for free               1.0
# 5                   NaN       own               1.0
# ..                  ...       ...               ...
# 498                 NaN       own               1.0
# 499                 NaN       own               1.0
# 500                 NaN       own               1.0
# 501                 NaN  for free               1.0
# 502                 NaN       own               1.0
#
#                            job  num_dependents foreign_worker class
# 1           unskilled resident             1.0            yes  good
# 2                      skilled             2.0            yes  good
# 3                      skilled             1.0            yes   bad
# 4                      skilled             2.0            yes  good
# 5                      skilled             1.0            yes  good
# ..                         ...             ...            ...   ...
# 498         unskilled resident             1.0            yes  good
# 499  high qualif/self emp/mgmt             1.0            yes  good
# 500                    skilled             1.0            yes  good
# 501                    skilled             1.0            yes   bad
# 502                    skilled             1.0            yes  good
#
# [502 rows x 18 columns]

# %%
credit_df1.isnull().mean()
# Out:
# checking_status           0.000
# duration                  0.000
# credit_history            0.000
# purpose                   0.000
# credit_amount             0.000
# savings_status            0.000
# employment                0.000
# installment_commitment    0.000
# other_parties             0.904
# property_magnitude        0.000
# age                       0.000
# other_payment_plans       0.805
# housing                   0.000
# existing_credits          0.000
# job                       0.000
# num_dependents            0.000
# foreign_worker            0.000
# class                     0.000
# dtype: float64

# %%
credit_df1 = credit_df1.drop(['other_parties', 'other_payment_plans'], axis = 1);

# %%
credit_df1.isnull().sum()
# Out:
# checking_status           0
# duration                  0
# credit_history            0
# purpose                   0
# credit_amount             0
# savings_status            0
# employment                0
# installment_commitment    0
# property_magnitude        0
# age                       0
# housing                   0
# existing_credits          0
# job                       0
# num_dependents            0
# foreign_worker            0
# class                     0
# dtype: int64

# %%
credit_df1
# Out:
#     checking_status  duration                  credit_history  \
# 1          0<=X<200      18.0                   existing paid
# 2             >=200       6.0  critical/other existing credit
# 3                <0      24.0                   existing paid
# 4                <0      36.0                   existing paid
# 5             >=200       9.0                   existing paid
# ..              ...       ...                             ...
# 498              <0      12.0                   existing paid
# 499              <0      30.0                   existing paid
# 500              <0      12.0                   existing paid
# 501              <0      45.0                   existing paid
# 502        0<=X<200      45.0  critical/other existing credit
#
#                  purpose  credit_amount savings_status employment  \
# 1               radio/tv         1301.0           <100        >=7
# 2                new car         1323.0     100<=X<500        >=7
# 3                new car         3123.0           <100         <1
# 4               used car         5493.0           <100        >=7
# 5               radio/tv         1126.0     100<=X<500        >=7
# ..                   ...            ...            ...        ...
# 498  furniture/equipment         1736.0           <100     4<=X<7
# 499             used car         3857.0           <100     1<=X<4
# 500             radio/tv          804.0           <100        >=7
# 501             radio/tv         1845.0           <100     1<=X<4
# 502             used car         4576.0     100<=X<500          0
#
#      installment_commitment property_magnitude   age   housing  \
# 1                       4.0        real estate  32.0       own
# 2                       2.0                car  28.0       own
# 3                       4.0     life insurance  27.0       own
# 4                       2.0  no known property  42.0  for free
# 5                       2.0        real estate  49.0       own
# ..                      ...                ...   ...       ...
# 498                     3.0        real estate  31.0       own
# 499                     4.0     life insurance  40.0       own
# 500                     4.0                car  38.0       own
# 501                     4.0  no known property  23.0  for free
# 502                     3.0                car  27.0       own
#
#      existing_credits                        job  num_dependents  \
# 1                 1.0         unskilled resident             1.0
# 2                 2.0                    skilled             2.0
# 3                 1.0                    skilled             1.0
# 4                 1.0                    skilled             2.0
# 5                 1.0                    skilled             1.0
# ..                ...                        ...             ...
# 498               1.0         unskilled resident             1.0
# 499               1.0  high qualif/self emp/mgmt             1.0
# 500               1.0                    skilled             1.0
# 501               1.0                    skilled             1.0
# 502               1.0                    skilled             1.0
#
#     foreign_worker class
# 1              yes  good
# 2              yes  good
# 3              yes   bad
# 4              yes  good
# 5              yes  good
# ..             ...   ...
# 498            yes  good
# 499            yes  good
# 500            yes  good
# 501            yes   bad
# 502            yes  good
#
# [502 rows x 16 columns]
